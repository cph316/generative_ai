# %% [markdown]
# <a href="https://colab.research.google.com/github/cph316/generative_ai/blob/main/%E3%80%90HW1%E3%80%91%E7%95%AB%E4%B8%80%E5%80%8B%E5%87%BD%E6%95%B8%E5%9C%96%E5%BD%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌸 極座標花瓣曲線 (Rose Curve) 🎨
#
# 繪製 **極座標花瓣曲線（Rose Curve）**
# 它的數學表達式為：
# \[
# r = sin(k*theta)
# \]
# 其中：
# - *\( k \) 決定花瓣數量*
# - 在極座標上繪出對稱的圖案，並將其曲線設定為 **粉紅色**，並移除了所有軸標籤，讓畫面簡潔。🌷

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定極座標和花瓣數量
theta = np.linspace(0, 2*np.pi, 400)
k = 5
r = np.sin(k * theta)

# 繪製極座標圖
plt.figure(figsize=(6, 6))
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r, color='pink', linewidth=2)

# 美化圖形(移除極座標刻度,移除半徑標籤,移除角度標籤)
ax.set_rticks([])
ax.set_yticklabels([])
ax.set_xticklabels([])

# 設定標題
ax.set_title("Rose Curve", fontsize=18, color='blue')

plt.show()
